# %%
import duckdb

duck = duckdb.connect()

duck.sql("select text, length(text) as text_length from 'corpus/wikipedia-nno.parquet' order by text_length desc limit 10").df()
# Out:
#                                                 text  text_length
# 0  '''Rock''' er ein sjanger innanfor rytmisk mus...        95749
# 1  Trearbeid med BDS sitt merke. Bygningen til De...        95016
# 2  '''Jemen''' (arabisk اليَمَن, ''al-Yaman''), o...        84796
# 3  '''Sovjetunionen''' eller '''Sovjetsamveldet''...        84253
# 4  '''Elvis Aaron Presley''' () var ein amerikans...        80241
# 5  '''Jesus''' (ca. 4 f.Kr.–30/33 e.Kr.), også kj...        76373
# 6  '''Saudi-Arabia''' (arabisk السعودية, ''as-Su'...        75589
# 7  '''Niårskrigen''' (1688–1697), også kalla '''S...        74960
# 8  Fil:Bayeux_Tapestry_scene51_Battle_of_Hastings...        73931
# 9  '''Iran''' (farsi ایران), før 1934 kalla '''Pe...        69138
